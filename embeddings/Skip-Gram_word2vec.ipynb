# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
t = 1e-5
word_counter = Counter(int_words)
total_count = len(words)

word_f = {word: count/total_count for word, count in word_counter.items()}

discard_prob = {word: 1 - np.sqrt(t/word_f[word]) for word in word_counter.keys()}
train_words = [word for word in int_words if np.random.random() > discard_prob[word]]     # The final subsampled word list

# %%
print("{} words out of {} were picked".format(len(train_words), len(int_words)))
# Out:
# 4625957 words out of 16680599 were picked

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.choice(window_size, 1)[0]  # note: don't forget [0]
    start = (idx - R) if (idx > R) else 0
    stop = idx + R + 1
    target_words = set(words[start:idx] +  words[idx+1:stop])  # note: set(setA + setB)
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y
# for x_i, y_i = (x_i-R, ...., x_i+R), we create:
# x = [..., x_i, ..., x_i, ...] , y = [..., x_i-R, ..., x_i+R, ...]

# %%
#next(get_batches(train_words, batch_size = 10, window_size = 5))

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(dtype=tf.int32, shape=[None], name='inputs')
    labels = tf.placeholder(dtype=tf.int32, shape=[None, 1], name = 'outputs')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 300 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    # create softmax weight matrix here: NOTE: here W is n_vocab X n_embedding (Wx + b)
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) 
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.7760 0.0498 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.7498 0.0423 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.6123 0.0435 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.7087 0.0402 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.6080 0.0416 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.6808 0.0426 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.6161 0.0422 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.6656 0.0415 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.5770 0.0425 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.5342 0.0399 sec/batch
# Nearest to while: duma, batgirl, theorie, mujibur, parked, turkic, holding, linguistic,
# Nearest to more: cardinals, acacias, ethnographers, seam, animator, windward, fink, lmi,
# Nearest to years: fansite, asic, migraine, blisters, andamans, empowering, hertz, connacht,
# Nearest to th: hebert, deferment, villagers, susie, pyrolytic, odo, rosslyn, martindale,
# Nearest to of: blueprints, hook, muscovites, akh, blackjacks, alleanza, dispelled, dg,
# Nearest to two: integrin, netanya, is, zoetrope, allegedly, reunite, pasteurization, sisters,
# Nearest to where: e, obstructions, ilmarinen, poland, medals, heimdallr, retirees, mars,
# Nearest to by: dusky, lrt, eraclius, orthography, hudd, venice, casserole, react,
# Nearest to animals: heh, vauquelin, library, sponsor, loam, archiepiscopal, oprah, habeas,
# Nearest to shown: kate, regencies, jumbled, sabo, romanic, madura, very, swiftly,
# Nearest to applied: scalia, enterprise, zulus, tunisian, altar, tydfil, transactions, prophesies,
# Nearest to alternative: dugme, olav, magyar, chunks, asexual, dissuade, rence, lizard,
# Nearest to assembly: rearwards, gir, tackle, aiding, meiotic, cic, gutar, greedy,
# Nearest to ice: ufo, attesting, stacey, typhus, stadium, wickets, bromides, eph,
# Nearest to woman: hardwoods, hamsun, xn, bol, unbridled, okinawan, ostara, srpska,
# Nearest to defense: overseen, hosni, summarised, sayed, bongos, pcm, rt, heraldic,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5750 0.0491 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4804 0.0415 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.4328 0.0407 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.3518 0.0396 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.3027 0.0389 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.2827 0.0415 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1964 0.0417 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.1738 0.0382 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.1234 0.0380 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0882 0.0365 sec/batch
# Nearest to while: price, holding, batgirl, theorie, duma, linguistic, turkic, mujibur,
# Nearest to more: cardinals, acacias, ethnographers, cultivation, windward, animator, metaphorically, enlist,
# Nearest to years: procedural, migraine, committed, avoided, book, andamans, improvements, whose,
# Nearest to th: hebert, deferment, villagers, rock, martindale, odo, susie, pyrolytic,
# Nearest to of: trade, blueprints, accountable, hook, variety, akh, video, muscovites,
# Nearest to two: skyscraper, ago, integrin, lb, netanya, roadways, recently, allegedly,
# Nearest to where: e, obstructions, town, several, poland, ilmarinen, medals, mars,
# Nearest to by: dusky, orthography, venice, eraclius, react, hudd, lrt, championships,
# Nearest to animals: library, vauquelin, violent, sponsor, ebla, limbs, heh, relations,
# Nearest to shown: very, kate, jumbled, regencies, sabo, romanic, synclavier, careful,
# Nearest to applied: enterprise, scalia, transactions, altar, invested, tunisian, diatomic, affiliation,
# Nearest to alternative: dugme, crackers, olav, magyar, chunks, senators, highways, statisticians,
# Nearest to assembly: greedy, rearwards, tackle, hone, homeomorphisms, meiotic, wakefield, ignition,
# Nearest to ice: ufo, attesting, typhus, stadium, wickets, anthracite, stacey, desmond,
# Nearest to woman: hardwoods, bol, hamsun, kinds, eluded, xn, million, sake,
# Nearest to defense: overseen, summarised, sayed, hosni, rt, bongos, pcm, widest,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 5.0476 0.0441 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 5.0213 0.0437 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9870 0.0395 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.9732 0.0415 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8943 0.0414 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8854 0.0448 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8842 0.0469 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8587 0.0412 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8584 0.0398 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.8459 0.0410 sec/batch
# Nearest to while: price, turkic, duma, parked, holding, linguistic, batgirl, theorie,
# Nearest to more: cardinals, ethnographers, acacias, animator, insult, windward, metaphorically, added,
# Nearest to years: committed, fansite, migraine, hertz, asic, avoided, blisters, andamans,
# Nearest to th: hebert, villagers, deferment, odo, rock, pyrolytic, rosslyn, recommended,
# Nearest to of: trade, blueprints, accountable, variety, unencumbered, landless, conflict, akh,
# Nearest to two: authorize, skyscraper, lb, six, zoetrope, reunite, inverses, ago,
# Nearest to where: obstructions, e, mars, retirees, ilmarinen, medals, desirability, poland,
# Nearest to by: orthography, dusky, eraclius, venice, hudd, lrt, react, handled,
# Nearest to animals: library, lifelong, sponsor, violent, vauquelin, ebla, limbs, satirist,
# Nearest to shown: very, kate, jumbled, regencies, synclavier, careful, romanic, sabo,
# Nearest to applied: transactions, enterprise, scalia, altar, invested, augment, tunisian, combatant,
# Nearest to alternative: dugme, olav, chunks, reichstag, crackers, magyar, senators, humans,
# Nearest to assembly: aiding, greedy, supreme, tackle, wakefield, hone, homeomorphisms, meiotic,
# Nearest to ice: ufo, attesting, stadium, wickets, typhus, calculus, desmond, anthracite,
# Nearest to woman: hardwoods, bol, hamsun, eluded, kinds, lightweight, million, sake,
# Nearest to defense: overseen, summarised, sayed, hosni, heraldic, rt, pulses, pcm,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.8379 0.0426 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.8391 0.0397 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7834 0.0384 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7919 0.0405 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.8147 0.0416 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7623 0.0416 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7747 0.0427 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7737 0.0385 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7555 0.0400 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6997 0.0395 sec/batch
# Nearest to while: duma, price, turkic, holding, batgirl, tastes, parked, linguistic,
# Nearest to more: cardinals, ethnographers, acacias, windward, metaphorically, enlist, anytime, insult,
# Nearest to years: fansite, crusaders, committed, asic, migraine, blisters, destroying, connacht,
# Nearest to th: hebert, odo, deferment, rosslyn, villagers, pyrolytic, rock, martindale,
# Nearest to of: landless, trade, alleanza, blueprints, conflict, unencumbered, abolish, hook,
# Nearest to two: six, authorize, lb, chew, skyscraper, zoetrope, biochemist, reunite,
# Nearest to where: e, obstructions, ilmarinen, retirees, mars, beams, desirability, medals,
# Nearest to by: eraclius, dusky, venice, lrt, orthography, hudd, react, badr,
# Nearest to animals: vauquelin, lifelong, sponsor, limbs, ebla, violent, corrected, gastrointestinal,
# Nearest to shown: very, kate, regencies, jumbled, synclavier, romanic, swiftly, careful,
# Nearest to applied: enterprise, transactions, scalia, altar, augment, feedbacks, diatomic, tunisian,
# Nearest to alternative: olav, dugme, chunks, magyar, reichstag, crackers, lap, asexual,
# Nearest to assembly: supreme, aiding, hone, greedy, wakefield, tackle, bronx, homeomorphisms,
# Nearest to ice: ufo, attesting, wickets, stadium, typhus, desmond, runners, generalisations,
# Nearest to woman: hardwoods, hamsun, bol, eluded, okinawan, srpska, xn, lightweight,
# Nearest to defense: overseen, summarised, sayed, hosni, heraldic, singly, pcm, bongos,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.7130 0.0425 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.7064 0.0404 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6783 0.0396 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6715 0.0402 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6551 0.0419 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6895 0.0409 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6190 0.0319 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5499 0.0413 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5114 0.0429 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5226 0.0418 sec/batch
# Nearest to while: duma, price, batgirl, turkic, parked, tastes, holding, linguistic,
# Nearest to more: cardinals, ethnographers, acacias, anytime, lmi, insult, metaphorically, windward,
# Nearest to years: fansite, crusaders, asic, destroying, andamans, connacht, empowering, committed,
# Nearest to th: hebert, odo, villagers, deferment, rosslyn, pyrolytic, rock, sackville,
# Nearest to of: landless, conflict, variety, blueprints, boundary, belvedere, unencumbered, populace,
# Nearest to two: six, authorize, biochemist, chew, lb, zero, reunite, skyscraper,
# Nearest to where: e, obstructions, retirees, mars, ilmarinen, desirability, completeness, beams,
# Nearest to by: eraclius, hudd, dusky, badr, lrt, orthography, react, liqueurs,
# Nearest to animals: lifelong, vauquelin, gastrointestinal, limbs, oprah, sponsor, ebla, repeats,
# Nearest to shown: very, regencies, kate, romanic, jumbled, careful, sabo, synclavier,
# Nearest to applied: transactions, enterprise, scalia, feedbacks, altar, augment, planetmath, diatomic,
# Nearest to alternative: dugme, olav, reichstag, magyar, chunks, crackers, patently, interlisp,
# Nearest to assembly: supreme, aiding, greedy, wakefield, legislative, tui, tackle, meiotic,
# Nearest to ice: ufo, attesting, wickets, stadium, typhus, idealised, scarce, desmond,
# Nearest to woman: hardwoods, bol, srpska, hamsun, eluded, okinawan, serling, estados,
# Nearest to defense: overseen, sayed, summarised, hosni, heraldic, pcm, singly, mmu,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4912 0.0457 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4690 0.0435 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4564 0.0396 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5332 0.0413 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4727 0.0424 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4702 0.0416 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4355 0.0402 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3781 0.0399 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4108 0.0410 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4190 0.0418 sec/batch
# Nearest to while: duma, price, batgirl, turkic, parked, tastes, holding, inner,
# Nearest to more: cardinals, ethnographers, acacias, insult, lmi, anytime, windward, enlist,
# Nearest to years: crusaders, fansite, asic, destroying, andamans, connacht, empowering, committed,
# Nearest to th: hebert, odo, deferment, villagers, rosslyn, pyrolytic, interchanged, sackville,
# Nearest to of: akh, blueprints, belvedere, populace, unencumbered, boundary, abolish, alleanza,
# Nearest to two: six, lb, zero, authorize, reunite, integrin, chew, qazaqstan,
# Nearest to where: obstructions, e, completeness, retirees, ilmarinen, exponentiation, tambourine, mars,
# Nearest to by: eraclius, hudd, orthography, lrt, badr, react, dusky, clandestinely,
# Nearest to animals: vauquelin, lifelong, limbs, nerve, gastrointestinal, carnivores, oprah, artiodactyla,
# Nearest to shown: very, regencies, jumbled, kate, synclavier, swiftly, careful, romanic,
# Nearest to applied: enterprise, transactions, scalia, altar, feedbacks, planetmath, diatomic, augment,
# Nearest to alternative: dugme, reichstag, olav, chunks, magyar, humans, crackers, manhood,
# Nearest to assembly: supreme, legislative, committee, clause, aiding, tui, greedy, wakefield,
# Nearest to ice: ufo, attesting, wickets, stadium, scarce, mosquitos, idealised, flammable,
# Nearest to woman: srpska, hardwoods, eluded, okinawan, hamsun, bol, xn, serling,
# Nearest to defense: overseen, sayed, summarised, hosni, heraldic, mmu, pcm, singly,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4193 0.0473 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3742 0.0432 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4384 0.0415 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3936 0.0423 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4240 0.0406 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4303 0.0406 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3734 0.0413 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3663 0.0422 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4075 0.0434 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3592 0.0418 sec/batch
# Nearest to while: duma, parked, tastes, batgirl, turkic, price, holding, sturgeon,
# Nearest to more: cardinals, acacias, ethnographers, insult, lmi, anytime, metaphorically, windward,
# Nearest to years: fansite, crusaders, asic, destroying, connacht, andamans, empowering, committed,
# Nearest to th: hebert, odo, villagers, rosslyn, deferment, interchanged, presaging, sackville,
# Nearest to of: blackjacks, boundary, enrich, unencumbered, akh, dpi, soderbergh, blueprints,
# Nearest to two: six, zero, lb, reunite, authorize, tacked, chew, inverses,
# Nearest to where: obstructions, retirees, completeness, exponentiation, beams, tambourine, ilmarinen, e,
# Nearest to by: eraclius, hudd, orthography, lrt, badr, dusky, react, handled,
# Nearest to animals: vauquelin, nerve, carnivores, limbs, gastrointestinal, lifelong, aquatic, ebla,
# Nearest to shown: very, regencies, kate, jumbled, careful, synclavier, swiftly, sabo,
# Nearest to applied: enterprise, transactions, scalia, altar, feedbacks, geneticists, planetmath, diatomic,
# Nearest to alternative: dugme, olav, reichstag, chunks, address, interlisp, patently, asic,
# Nearest to assembly: supreme, legislative, constituencies, committee, tui, aiding, affairs, clause,
# Nearest to ice: ufo, attesting, stadium, wickets, idealised, mosquitos, correggio, quantity,
# Nearest to woman: srpska, eluded, hardwoods, serling, okinawan, ntc, ackroyd, slade,
# Nearest to defense: overseen, hosni, sayed, summarised, heraldic, maimon, privatisation, mmu,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3603 0.0440 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4073 0.0424 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3436 0.0426 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3436 0.0415 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3985 0.0418 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3671 0.0414 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3767 0.0392 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3888 0.0355 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3286 0.0406 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3358 0.0457 sec/batch
# Nearest to while: duma, turkic, parked, batgirl, tastes, price, holding, thanked,
# Nearest to more: ethnographers, acacias, lmi, cardinals, insult, windward, anytime, metaphorically,
# Nearest to years: crusaders, asic, destroying, fansite, andamans, connacht, empowering, households,
# Nearest to th: hebert, odo, deferment, interchanged, rosslyn, villagers, presaging, subsidised,
# Nearest to of: populace, blackjacks, boundary, unencumbered, akh, enrich, primigenius, abolish,
# Nearest to two: six, zero, five, lb, authorize, inverses, phagspa, tacked,
# Nearest to where: obstructions, retirees, completeness, ilmarinen, beams, exponentiation, hayao, e,
# Nearest to by: eraclius, hudd, lrt, orthography, handled, badr, dusky, liqueurs,
# Nearest to animals: vauquelin, limbs, nerve, carnivores, gastrointestinal, artiodactyla, ebla, prey,
# Nearest to shown: very, regencies, kate, jumbled, careful, synclavier, swiftly, sabo,
# Nearest to applied: transactions, scalia, enterprise, feedbacks, altar, planetmath, subconscious, geneticists,
# Nearest to alternative: dugme, interlisp, olav, address, asic, chunks, reichstag, rence,
# Nearest to assembly: supreme, legislative, constituencies, committee, affairs, aiding, clause, tui,
# Nearest to ice: ufo, attesting, idealised, correggio, stadium, mosquitos, flammable, scarce,
# Nearest to woman: srpska, eluded, serling, hardwoods, okinawan, fertility, ntc, envision,
# Nearest to defense: overseen, hosni, sayed, summarised, heraldic, maimon, privatisation, lebanese,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3309 0.0469 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2820 0.0424 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3790 0.0387 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3560 0.0406 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3693 0.0403 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2818 0.0440 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3010 0.0406 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3557 0.0397 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2047 0.0386 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2879 0.0424 sec/batch
# Nearest to while: duma, turkic, batgirl, holding, tastes, parked, rav, thanked,
# Nearest to more: lmi, ethnographers, acacias, cardinals, windward, anytime, insult, cultivation,
# Nearest to years: crusaders, destroying, migrant, asic, andamans, empowering, advantageously, fansite,
# Nearest to th: hebert, odo, deferment, interchanged, subsidised, sackville, nation, roush,
# Nearest to of: boundary, blackjacks, unencumbered, muscovites, disloyal, dpi, populace, akh,
# Nearest to two: six, zero, five, lb, four, authorize, chew, biochemist,
# Nearest to where: obstructions, ilmarinen, completeness, retirees, e, exponentiation, beams, hayao,
# Nearest to by: eraclius, hudd, lrt, badr, dusky, liqueurs, orthography, razed,
# Nearest to animals: vauquelin, artiodactyla, carnivores, limbs, aquatic, ebla, nerve, gastrointestinal,
# Nearest to shown: very, kate, regencies, jumbled, careful, synclavier, romanic, swiftly,
# Nearest to applied: transactions, enterprise, scalia, feedbacks, altar, geneticists, diatomic, planetmath,
# Nearest to alternative: dugme, interlisp, asic, rence, olav, retailer, reichstag, address,
# Nearest to assembly: constituencies, supreme, legislative, affairs, committee, clause, proportional, tui,
# Nearest to ice: attesting, ufo, correggio, idealised, stadium, mosquitos, flammable, scarce,
# Nearest to woman: srpska, fertility, eluded, serling, aids, okinawan, nationality, envision,
# Nearest to defense: overseen, sayed, hosni, summarised, heraldic, lebanese, maimon, referral,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2927 0.0435 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2888 0.0398 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3231 0.0217 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2165 0.0416 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2107 0.0422 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1761 0.0436 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1884 0.0401 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1654 0.0406 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.1701 0.0401 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1407 0.0413 sec/batch
# Nearest to while: parked, duma, turkic, batgirl, price, holding, tastes, inner,
# Nearest to more: lmi, ethnographers, acacias, cardinals, anytime, insult, cultivation, windward,
# Nearest to years: crusaders, couples, households, advantageously, andamans, asic, migrant, privates,
# Nearest to th: hebert, subsidised, odo, sackville, interchanged, emperor, deferment, roush,
# Nearest to of: boundary, akh, blackjacks, primigenius, enrich, dpi, populace, akii,
# Nearest to two: six, zero, lb, five, four, authorize, qazaqstan, gauleiter,
# Nearest to where: retirees, completeness, obstructions, ilmarinen, beams, exponentiation, tambourine, e,
# Nearest to by: eraclius, hudd, lrt, razed, badr, orthography, dusky, liqueurs,
# Nearest to animals: aquatic, vauquelin, artiodactyla, lifelong, carnivores, limbs, prey, nerve,
# Nearest to shown: very, regencies, kate, jumbled, careful, synclavier, romanic, sectioning,
# Nearest to applied: enterprise, scalia, transactions, feedbacks, altar, geneticists, diatomic, spleen,
# Nearest to alternative: dugme, interlisp, asic, rence, retailer, reichstag, dinghy, olav,
# Nearest to assembly: constituencies, supreme, legislative, aiding, proportional, tui, clause, consultative,
# Nearest to ice: ufo, attesting, correggio, idealised, mosquitos, stadium, flammable, scarce,
# Nearest to woman: srpska, fertility, serling, eluded, children, nationality, envision, okinawan,
# Nearest to defense: overseen, hosni, sayed, summarised, referral, heraldic, maimon, mmu,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2099 0.0440 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1920 0.0418 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.1938 0.0418 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1184 0.0412 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1405 0.0421 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1492 0.0425 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1313 0.0434 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1344 0.0405 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1904 0.0410 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1513 0.0408 sec/batch
# Nearest to while: turkic, duma, parked, batgirl, price, tastes, rav, holding,
# Nearest to more: lmi, ethnographers, anytime, acacias, cardinals, insult, rll, cultivation,
# Nearest to years: couples, advantageously, households, crusaders, migrant, asic, andamans, calabrian,
# Nearest to th: hebert, subsidised, sackville, deferment, odo, interchanged, emperor, roush,
# Nearest to of: blackjacks, primigenius, boundary, replenish, enrich, preinstalled, akh, soderbergh,
# Nearest to two: zero, six, five, lb, four, qazaqstan, authorize, tacked,
# Nearest to where: retirees, obstructions, ilmarinen, completeness, tambourine, exponentiation, beams, hayao,
# Nearest to by: eraclius, hudd, lrt, orthography, react, liqueurs, basf, dusky,
# Nearest to animals: carnivores, aquatic, artiodactyla, lifelong, vauquelin, prey, limbs, nerve,
# Nearest to shown: very, regencies, kate, jumbled, careful, synclavier, sectioning, swiftly,
# Nearest to applied: scalia, enterprise, transactions, feedbacks, diatomic, geneticists, altar, spleen,
# Nearest to alternative: dugme, interlisp, asic, rence, retailer, reichstag, dinghy, purpose,
# Nearest to assembly: constituencies, supreme, legislative, proportional, aiding, affairs, tui, committee,
# Nearest to ice: idealised, attesting, flammable, correggio, mosquitos, ufo, desmond, stadium,
# Nearest to woman: fertility, srpska, serling, children, eluded, nationality, aids, poems,
# Nearest to defense: overseen, hosni, sayed, heraldic, summarised, referral, maimon, lebanese,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1316 0.0429 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.1760 0.0419 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1406 0.0374 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1296 0.0417 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1837 0.0424 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1579 0.0457 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1677 0.0429 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1207 0.0397 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1162 0.0419 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1726 0.0411 sec/batch
# Nearest to while: duma, batgirl, turkic, parked, inner, tastes, price, ministered,
# Nearest to more: lmi, ethnographers, anytime, acacias, cardinals, beelzebub, insult, cultivation,
# Nearest to years: advantageously, couples, migrant, crusaders, calabrian, skiers, permo, astute,
# Nearest to th: hebert, subsidised, interchanged, emperor, sackville, clamshell, landgrave, early,
# Nearest to of: blackjacks, a, primigenius, enrich, the, boundary, nichiren, consciences,
# Nearest to two: zero, six, five, four, lb, one, authorize, phagspa,
# Nearest to where: obstructions, retirees, completeness, ilmarinen, exponentiation, beams, tambourine, e,
# Nearest to by: eraclius, hudd, lrt, orthography, snell, dusky, misanthropy, razed,
# Nearest to animals: carnivores, aquatic, prey, artiodactyla, limbs, reptiles, vauquelin, nerve,
# Nearest to shown: very, regencies, kate, jumbled, synclavier, swiftly, careful, sectioning,
# Nearest to applied: enterprise, scalia, transactions, feedbacks, diatomic, geneticists, altar, axopods,
# Nearest to alternative: dugme, interlisp, asic, rence, retailer, purpose, beetles, dinghy,
# Nearest to assembly: constituencies, supreme, legislative, aiding, proportional, affairs, clause, consultative,
# Nearest to ice: idealised, mosquitos, correggio, ufo, attesting, flammable, stadium, desmond,
# Nearest to woman: fertility, srpska, serling, children, eluded, nationality, aids, poems,
# Nearest to defense: overseen, sayed, hosni, referral, heraldic, maimon, summarised, rebuffed,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1554 0.0392 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1433 0.0367 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1380 0.0407 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1546 0.0390 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1041 0.0427 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1132 0.0408 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1385 0.0417 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.0840 0.0386 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1606 0.0399 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1890 0.0417 sec/batch
# Nearest to while: duma, price, turkic, ministered, batgirl, rav, inner, parked,
# Nearest to more: lmi, ethnographers, anytime, cardinals, acacias, insult, fink, enlist,
# Nearest to years: crusaders, advantageously, days, entertainers, calabrian, couples, migrant, avoided,
# Nearest to th: subsidised, hebert, sackville, landgrave, clamshell, interchanged, deferment, taff,
# Nearest to of: the, blackjacks, a, enrich, accountable, cloister, landless, demokratika,
# Nearest to two: zero, six, five, one, four, three, authorize, eight,
# Nearest to where: ilmarinen, obstructions, retirees, completeness, town, e, exponentiation, syllabary,
# Nearest to by: eraclius, hudd, lrt, snell, orthography, badr, venice, razed,
# Nearest to animals: carnivores, aquatic, prey, reptiles, artiodactyla, limbs, suborder, lifelong,
# Nearest to shown: very, kate, regencies, jumbled, sectioning, synclavier, swiftly, charset,
# Nearest to applied: scalia, enterprise, transactions, altar, feedbacks, geneticists, diatomic, axopods,
# Nearest to alternative: dugme, interlisp, asic, retailer, rence, gottfredson, beetles, purpose,
# Nearest to assembly: constituencies, supreme, aiding, legislative, committee, affairs, consultative, clause,
# Nearest to ice: correggio, attesting, ufo, mosquitos, desmond, idealised, flammable, generalisations,
# Nearest to woman: fertility, srpska, serling, children, eluded, nationality, poems, aids,
# Nearest to defense: overseen, sayed, hosni, heraldic, referral, maimon, summarised, lebanese,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.1769 0.0408 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.0826 0.0402 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.0970 0.0399 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1072 0.0400 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 3.9775 0.0435 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1369 0.0427 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1109 0.0404 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1172 0.0407 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1608 0.0118 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0426 0.0375 sec/batch
# Nearest to while: duma, inner, turkic, batgirl, merging, ministered, price, teshuva,
# Nearest to more: lmi, ethnographers, anytime, cardinals, cultivation, insult, acacias, beelzebub,
# Nearest to years: advantageously, days, migrant, couples, crusaders, calabrian, entertainers, andamans,
# Nearest to th: subsidised, hebert, sackville, nation, landgrave, early, taff, clamshell,
# Nearest to of: the, a, blackjacks, foreknowledge, and, demokratika, boundary, unsophisticated,
# Nearest to two: zero, six, five, four, one, lb, three, authorize,
# Nearest to where: ilmarinen, obstructions, retirees, completeness, exponentiation, town, leased, e,
# Nearest to by: eraclius, hudd, lrt, orthography, snell, liqueurs, swordsmen, razed,
# Nearest to animals: carnivores, aquatic, artiodactyla, prey, lifelong, limbs, vauquelin, chordates,
# Nearest to shown: very, kate, regencies, sectioning, jumbled, romanic, charset, swiftly,
# Nearest to applied: scalia, enterprise, transactions, altar, diatomic, scorpius, geneticists, feedbacks,
# Nearest to alternative: dugme, interlisp, asic, retailer, rence, beetles, dinghy, gottfredson,
# Nearest to assembly: constituencies, supreme, legislative, aiding, proportional, committee, consultative, clause,
# Nearest to ice: mosquitos, correggio, attesting, ufo, idealised, desmond, flammable, stadium,
# Nearest to woman: fertility, srpska, children, serling, nationality, eluded, envision, okinawan,
# Nearest to defense: overseen, sayed, hosni, heraldic, referral, lebanese, maimon, rasmus,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0193 0.0415 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0156 0.0429 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0384 0.0404 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0166 0.0402 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0775 0.0375 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0197 0.0407 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0427 0.0418 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0663 0.0428 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0767 0.0419 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.9705 0.0419 sec/batch
# Nearest to while: duma, inner, parked, price, ministered, turkic, briefly, merging,
# Nearest to more: lmi, anytime, ethnographers, often, cardinals, cultivation, insult, acacias,
# Nearest to years: advantageously, couples, migrant, five, days, andamans, calabrian, entertainers,
# Nearest to th: subsidised, hebert, sackville, clamshell, early, landgrave, centuries, susie,
# Nearest to of: the, a, primigenius, blackjacks, boundary, and, demokratika, foreknowledge,
# Nearest to two: zero, six, five, four, one, three, lb, seven,
# Nearest to where: ilmarinen, retirees, obstructions, town, completeness, leased, tambourine, desirability,
# Nearest to by: hudd, eraclius, lrt, snell, orthography, handled, swordsmen, razed,
# Nearest to animals: aquatic, carnivores, artiodactyla, lifelong, limbs, prey, chordates, komodo,
# Nearest to shown: very, kate, regencies, sectioning, jumbled, swiftly, romanic, szko,
# Nearest to applied: scalia, enterprise, diatomic, transactions, altar, scorpius, feedbacks, geneticists,
# Nearest to alternative: dugme, interlisp, retailer, asic, subscription, rence, nihilist, beetles,
# Nearest to assembly: constituencies, supreme, aiding, legislative, proportional, committee, consultative, clause,
# Nearest to ice: mosquitos, correggio, attesting, ufo, idealised, flammable, desmond, stadium,
# Nearest to woman: fertility, children, srpska, nationality, serling, envision, okinawan, aids,
# Nearest to defense: overseen, sayed, hosni, heraldic, referral, lebanese, volunteered, decks,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9808 0.0430 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.9891 0.0405 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9607 0.0428 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0140 0.0409 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0209 0.0395 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0159 0.0414 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0037 0.0392 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0774 0.0400 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 3.9910 0.0363 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 3.9984 0.0401 sec/batch
# Nearest to while: duma, inner, ministered, parked, merging, price, turkic, briefly,
# Nearest to more: lmi, anytime, ethnographers, often, insult, cardinals, provability, cultivation,
# Nearest to years: advantageously, migrant, five, couples, days, entertainers, mortality, crusaders,
# Nearest to th: subsidised, hebert, deferment, clamshell, sackville, early, landgrave, blavatsky,
# Nearest to of: a, the, blackjacks, primigenius, and, boundary, laozi, unsophisticated,
# Nearest to two: zero, six, five, four, one, three, lb, eight,
# Nearest to where: ilmarinen, obstructions, retirees, completeness, e, exponentiation, town, leased,
# Nearest to by: eraclius, hudd, lrt, snell, orthography, the, handled, totally,
# Nearest to animals: carnivores, aquatic, prey, artiodactyla, limbs, lifelong, chordates, komodo,
# Nearest to shown: very, kate, sectioning, regencies, romanic, jumbled, charset, swiftly,
# Nearest to applied: scalia, enterprise, transactions, diatomic, geneticists, feedbacks, scorpius, altar,
# Nearest to alternative: dugme, retailer, interlisp, subscription, asic, rence, assumptions, rawls,
# Nearest to assembly: constituencies, supreme, legislative, aiding, consultative, proportional, committee, affairs,
# Nearest to ice: mosquitos, correggio, flammable, desmond, idealised, generalisations, attesting, ufo,
# Nearest to woman: children, fertility, serling, srpska, nationality, pomeroy, aids, eluded,
# Nearest to defense: overseen, sayed, hosni, heraldic, referral, lebanese, volunteered, widows,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0270 0.0428 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0594 0.0387 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0851 0.0413 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0021 0.0424 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0384 0.0404 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0219 0.0402 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0089 0.0373 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0046 0.0428 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0303 0.0419 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0465 0.0406 sec/batch
# Nearest to while: duma, inner, ministered, parked, turkic, merging, dissented, briefly,
# Nearest to more: lmi, anytime, ethnographers, cultivation, insult, beelzebub, freiherr, cardinals,
# Nearest to years: days, five, advantageously, migrant, crusaders, couples, calabrian, two,
# Nearest to th: subsidised, hebert, early, landgrave, centuries, one, clamshell, athos,
# Nearest to of: the, a, and, blackjacks, primigenius, accountable, which, boundary,
# Nearest to two: zero, six, five, four, one, three, seven, eight,
# Nearest to where: ilmarinen, obstructions, retirees, exponentiation, leased, e, completeness, town,
# Nearest to by: eraclius, the, hudd, lrt, snell, razed, totally, orthography,
# Nearest to animals: carnivores, aquatic, prey, artiodactyla, limbs, lifelong, komodo, chordates,
# Nearest to shown: very, kate, sectioning, regencies, swiftly, romanic, charset, jumbled,
# Nearest to applied: scalia, enterprise, altar, geneticists, diatomic, tars, transactions, feedbacks,
# Nearest to alternative: dugme, retailer, interlisp, asic, subscription, exploited, nihilist, rawls,
# Nearest to assembly: constituencies, aiding, supreme, legislative, proportional, consultative, unicameral, committee,
# Nearest to ice: mosquitos, correggio, generalisations, desmond, flammable, idealised, ufo, attesting,
# Nearest to woman: fertility, children, srpska, nationality, serling, expectancy, aids, eluded,
# Nearest to defense: overseen, heraldic, sayed, hosni, referral, lebanese, widows, training,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0291 0.0454 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9731 0.0400 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0157 0.0422 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0146 0.0392 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0694 0.0387 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.0751 0.0419 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.0751 0.0430 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0225 0.0433 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.9956 0.0414 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0092 0.0425 sec/batch
# Nearest to while: duma, inner, ministered, turkic, briefly, glass, merging, dissented,
# Nearest to more: lmi, anytime, ethnographers, cardinals, cultivation, freiherr, provability, often,
# Nearest to years: days, migrant, advantageously, five, aids, couples, two, crusaders,
# Nearest to th: subsidised, hebert, landgrave, early, centuries, kosrae, one, taff,
# Nearest to of: the, a, blackjacks, and, primigenius, pillaging, upsurge, which,
# Nearest to two: zero, six, five, four, one, three, seven, eight,
# Nearest to where: ilmarinen, retirees, e, obstructions, town, exponentiation, leased, vytautas,
# Nearest to by: hudd, eraclius, the, lrt, snell, orthography, totally, misanthropy,
# Nearest to animals: carnivores, aquatic, artiodactyla, prey, komodo, limbs, lifelong, nerve,
# Nearest to shown: very, kate, sectioning, regencies, romanic, swiftly, charset, synclavier,
# Nearest to applied: scalia, enterprise, diatomic, feedbacks, transactions, scorpius, tars, altar,
# Nearest to alternative: dugme, retailer, interlisp, asic, nihilist, subscription, rence, rawls,
# Nearest to assembly: constituencies, aiding, supreme, consultative, legislative, committee, menachem, ahmed,
# Nearest to ice: correggio, mosquitos, desmond, generalisations, flammable, netherland, attesting, idealised,
# Nearest to woman: fertility, children, nationality, srpska, serling, envision, aids, ringen,
# Nearest to defense: overseen, heraldic, sayed, hosni, referral, lebanese, maimon, volunteered,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9155 0.0440 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0103 0.0399 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0164 0.0417 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.9993 0.0429 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0300 0.0416 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 3.9728 0.0424 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0051 0.0403 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9130 0.0421 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9720 0.0415 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9416 0.0435 sec/batch
# Nearest to while: duma, inner, turkic, ministered, parked, briefly, glass, semiautomatic,
# Nearest to more: anytime, lmi, ethnographers, cultivation, trophic, cardinals, provability, often,
# Nearest to years: days, migrant, five, advantageously, couples, calabrian, brookline, skiers,
# Nearest to th: subsidised, early, centuries, landgrave, hebert, one, sackville, kosrae,
# Nearest to of: the, a, and, blackjacks, primigenius, which, unsophisticated, laozi,
# Nearest to two: zero, six, five, four, one, three, seven, eight,
# Nearest to where: ilmarinen, retirees, e, obstructions, completeness, town, leased, exponentiation,
# Nearest to by: hudd, eraclius, lrt, the, snell, totally, orthography, handled,
# Nearest to animals: carnivores, aquatic, artiodactyla, prey, komodo, chordates, lifelong, nerve,
# Nearest to shown: very, kate, sectioning, regencies, romanic, charset, international, swiftly,
# Nearest to applied: scalia, enterprise, transactions, altar, diatomic, tars, geneticists, axopods,
# Nearest to alternative: dugme, retailer, asic, interlisp, exploited, rawls, nihilist, subscription,
# Nearest to assembly: aiding, constituencies, consultative, rearwards, ahmed, presentational, committee, supreme,
# Nearest to ice: desmond, correggio, mosquitos, generalisations, netherland, idealised, ufo, flammable,
# Nearest to woman: fertility, children, nationality, srpska, serling, aids, envision, ringen,
# Nearest to defense: overseen, sayed, heraldic, referral, hosni, volunteered, rebuffed, lebanese,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9149 0.0394 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9230 0.0419 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9666 0.0433 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9762 0.0393 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0133 0.0422 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9224 0.0426 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8653 0.0401 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9413 0.0414 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.8510 0.0418 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9561 0.0420 sec/batch
# Nearest to while: duma, inner, glass, ministered, briefly, semiautomatic, parked, turkic,
# Nearest to more: anytime, lmi, ethnographers, trophic, cultivation, cardinals, repeated, often,
# Nearest to years: five, days, migrant, couples, advantageously, female, entertainers, brookline,
# Nearest to th: subsidised, early, centuries, landgrave, taff, hebert, one, century,
# Nearest to of: the, a, and, primigenius, blackjacks, which, two, in,
# Nearest to two: zero, five, six, four, one, three, eight, seven,
# Nearest to where: ilmarinen, retirees, obstructions, leased, e, vytautas, exponentiation, town,
# Nearest to by: hudd, eraclius, lrt, the, snell, handled, totally, elektra,
# Nearest to animals: carnivores, aquatic, prey, artiodactyla, chordates, komodo, limbs, lifelong,
# Nearest to shown: very, kate, sectioning, regencies, feud, romanic, charset, careful,
# Nearest to applied: scalia, enterprise, diatomic, cl, scorpius, tars, axopods, geneticists,
# Nearest to alternative: dugme, retailer, asic, exploited, interlisp, subscription, rawls, nihilist,
# Nearest to assembly: constituencies, aiding, supreme, legislative, committee, consultative, ahmed, unicameral,
# Nearest to ice: desmond, correggio, flammable, mosquitos, idealised, generalisations, dazed, netherland,
# Nearest to woman: children, fertility, nationality, srpska, serling, aids, envision, ringen,
# Nearest to defense: overseen, sayed, heraldic, referral, hosni, volunteered, decks, lebanese,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9392 0.0411 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9164 0.0374 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9637 0.0414 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9685 0.0393 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.9867 0.0423 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9286 0.0398 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9313 0.0436 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9594 0.0430 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9465 0.0416 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9259 0.0428 sec/batch
# Nearest to while: duma, inner, ministered, briefly, glass, mujibur, turkic, largely,
# Nearest to more: anytime, lmi, provability, ethnographers, often, cultivation, beelzebub, cardinals,
# Nearest to years: days, five, two, advantageously, fansite, migrant, year, brookline,
# Nearest to th: subsidised, one, early, landgrave, centuries, hebert, restrictive, taff,
# Nearest to of: the, a, and, blackjacks, which, in, two, primigenius,
# Nearest to two: zero, six, five, four, one, eight, seven, three,
# Nearest to where: ilmarinen, obstructions, retirees, e, leased, qattara, town, huddle,
# Nearest to by: the, eraclius, hudd, snell, lrt, of, relating, handled,
# Nearest to animals: carnivores, aquatic, prey, artiodactyla, chordates, komodo, invertebrates, mammalia,
# Nearest to shown: very, kate, sectioning, feud, charset, careful, regencies, phonemically,
# Nearest to applied: scalia, enterprise, geneticists, diatomic, tars, cl, axopods, altar,
# Nearest to alternative: dugme, retailer, asic, subscription, exploited, erd, interlisp, rawls,
# Nearest to assembly: constituencies, aiding, legislative, supreme, ahmed, unicameral, consultative, committee,
# Nearest to ice: desmond, correggio, generalisations, flammable, mosquitos, stadium, idealised, manslaughter,
# Nearest to woman: children, fertility, srpska, serling, nationality, aids, ringen, envision,
# Nearest to defense: overseen, heraldic, sayed, referral, hosni, volunteered, rebuffed, lebanese,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9805 0.0438 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9279 0.0420 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.8970 0.0403 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9552 0.0408 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9735 0.0434 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9385 0.0412 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9364 0.0427 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9158 0.0416 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9115 0.0420 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9663 0.0411 sec/batch
# Nearest to while: duma, inner, ministered, briefly, largely, turkic, glass, mujibur,
# Nearest to more: anytime, lmi, ethnographers, provability, beelzebub, cultivation, cardinals, perversity,
# Nearest to years: days, five, two, advantageously, migrant, year, female, asic,
# Nearest to th: subsidised, early, centuries, one, landgrave, century, taff, restrictive,
# Nearest to of: the, a, and, in, which, also, two, blackjacks,
# Nearest to two: zero, five, six, four, one, three, eight, seven,
# Nearest to where: ilmarinen, retirees, e, obstructions, qattara, exponentiation, vytautas, leased,
# Nearest to by: the, of, eraclius, lrt, hudd, relating, orthography, reflecting,
# Nearest to animals: carnivores, artiodactyla, aquatic, prey, chordates, komodo, mammalia, deer,
# Nearest to shown: very, kate, sectioning, feud, lurker, charset, phonemically, synclavier,
# Nearest to applied: scalia, tars, axopods, altar, enterprise, geneticists, birla, diatomic,
# Nearest to alternative: retailer, dugme, asic, subscription, exploited, potencies, interlisp, insurers,
# Nearest to assembly: aiding, constituencies, legislative, ahmed, consultative, committee, supreme, presidentially,
# Nearest to ice: desmond, correggio, flammable, mosquitos, generalisations, netherland, honeycomb, calculus,
# ...
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.7808 0.0377 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8001 0.0399 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8388 0.0394 sec/batch
# Nearest to while: ministered, duma, glass, briefly, in, comprise, more, punishes,
# Nearest to more: provability, much, anytime, most, often, perversity, airway, intuitive,
# Nearest to years: days, five, ago, year, half, at, seven, thirty,
# Nearest to th: early, century, subsidised, one, centuries, rd, restrictive, nd,
# Nearest to of: a, the, and, by, in, which, also, two,
# Nearest to two: zero, five, six, four, one, three, seven, eight,
# Nearest to where: ilmarinen, in, wpm, vytautas, e, hayao, qattara, retirees,
# Nearest to by: the, of, a, was, to, and, into, for,
# Nearest to animals: aquatic, carnivores, komodo, artiodactyla, chordates, deer, humans, classis,
# Nearest to shown: very, sectioning, feud, connective, each, documentaries, kate, szko,
# Nearest to applied: scalia, tars, applying, customarily, axopods, affiliation, submitting, unter,
# Nearest to alternative: retailer, erd, practice, dugme, potencies, assumptions, ttern, asic,
# Nearest to assembly: aiding, prentice, legislative, optimize, wharton, foundered, lddc, percussionist,
# Nearest to ice: desmond, generalisations, cream, correggio, canada, manslaughter, honeycomb, motions,
# Nearest to woman: children, nationality, serling, fertility, srpska, adjective, aids, her,
# Nearest to defense: selects, overseen, widows, referral, sayed, protective, heraldic, facilities,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.7874 0.0426 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8072 0.0406 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.7973 0.0420 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8196 0.0399 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.7979 0.0413 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8210 0.0417 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.7824 0.0408 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.7838 0.0417 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8101 0.0412 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8463 0.0400 sec/batch
# Nearest to while: duma, ministered, briefly, in, largely, glass, pleated, comprise,
# Nearest to more: provability, perversity, much, most, anytime, airway, often, two,
# Nearest to years: days, five, year, ago, seven, two, half, female,
# Nearest to th: century, early, centuries, subsidised, one, nd, restrictive, disintegration,
# Nearest to of: the, a, and, by, in, which, on, also,
# Nearest to two: zero, five, six, one, three, four, seven, eight,
# Nearest to where: ilmarinen, in, vytautas, some, wpm, qattara, result, hayao,
# Nearest to by: the, of, a, and, to, as, was, in,
# Nearest to animals: aquatic, carnivores, komodo, artiodactyla, chordates, humans, classis, deer,
# Nearest to shown: very, sectioning, feud, invalid, each, connective, szko, kate,
# Nearest to applied: scalia, applying, tars, customarily, axopods, etudes, eddic, navies,
# Nearest to alternative: retailer, erd, potencies, dugme, ttern, practice, assumptions, reminded,
# Nearest to assembly: aiding, legislative, prentice, optimize, wharton, foundered, consultative, marangella,
# Nearest to ice: desmond, generalisations, motions, cream, rims, canada, correggio, honeycomb,
# Nearest to woman: nationality, children, fertility, serling, srpska, adjective, girl, birth,
# Nearest to defense: selects, widows, overseen, iran, referral, sayed, heraldic, government,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8149 0.0393 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.7888 0.0407 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.7710 0.0402 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.7728 0.0393 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8371 0.0397 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.7950 0.0411 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9128 0.0387 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8551 0.0429 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8388 0.0428 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7747 0.0413 sec/batch
# Nearest to while: in, duma, ministered, briefly, glass, mujibur, largely, comprise,
# Nearest to more: provability, most, two, much, airway, zero, perversity, often,
# Nearest to years: days, five, two, year, female, half, seven, ago,
# Nearest to th: century, early, subsidised, centuries, one, restrictive, disintegration, florin,
# Nearest to of: the, a, and, by, in, which, also, on,
# Nearest to two: zero, five, six, four, three, one, seven, eight,
# Nearest to where: in, ilmarinen, qattara, vytautas, wpm, their, result, some,
# Nearest to by: the, of, a, and, was, one, as, to,
# Nearest to animals: artiodactyla, carnivores, komodo, chordates, aquatic, humans, classis, deer,
# Nearest to shown: very, sectioning, feud, documentaries, each, kate, andhra, szko,
# Nearest to applied: scalia, applying, tars, axopods, customarily, unter, zulus, navies,
# Nearest to alternative: retailer, erd, practice, dugme, potencies, ttern, assumptions, accept,
# Nearest to assembly: aiding, legislative, prentice, optimize, wharton, consultative, foundered, complaints,
# Nearest to ice: desmond, generalisations, correggio, motions, rims, canada, cream, hypothesised,
# Nearest to woman: nationality, children, fertility, serling, srpska, girl, adjective, her,
# Nearest to defense: selects, widows, iran, overseen, sayed, heraldic, government, referral,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7500 0.0419 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.7947 0.0392 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7619 0.0416 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.7977 0.0412 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.7880 0.0404 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8365 0.0412 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.7958 0.0316 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8131 0.0394 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.7218 0.0404 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8092 0.0402 sec/batch
# Nearest to while: duma, briefly, in, ministered, glass, more, and, pleated,
# Nearest to more: provability, much, perversity, most, airway, often, anytime, while,
# Nearest to years: days, five, year, half, two, ago, at, structure,
# Nearest to th: century, early, subsidised, centuries, one, rd, nd, florin,
# Nearest to of: the, a, and, by, in, or, which, also,
# Nearest to two: zero, five, six, four, one, three, seven, eight,
# Nearest to where: in, ilmarinen, e, vytautas, aquarius, were, hayao, qattara,
# Nearest to by: the, of, a, was, and, to, as, into,
# Nearest to animals: carnivores, artiodactyla, komodo, chordates, aquatic, humans, human, classis,
# Nearest to shown: very, sectioning, feud, connective, documentaries, andhra, invalid, each,
# Nearest to applied: tars, scalia, unter, waka, customarily, axopods, applying, etudes,
# Nearest to alternative: retailer, practice, erd, potencies, assumptions, dugme, ttern, exploited,
# Nearest to assembly: aiding, optimize, prentice, legislative, wharton, gir, complaints, consultative,
# Nearest to ice: desmond, generalisations, correggio, canada, cream, rims, manslaughter, hypothesised,
# Nearest to woman: nationality, fertility, children, serling, adjective, srpska, her, birth,
# Nearest to defense: selects, widows, overseen, referral, heraldic, government, sayed, iran,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7250 0.0386 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7824 0.0374 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7295 0.0400 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8268 0.0405 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.7959 0.0400 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8096 0.0409 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8412 0.0392 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7059 0.0394 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7488 0.0432 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7137 0.0400 sec/batch
# Nearest to while: ministered, duma, more, glass, on, briefly, and, in,
# Nearest to more: provability, much, often, most, than, two, number, perversity,
# Nearest to years: days, five, year, female, structure, half, two, seven,
# Nearest to th: century, early, subsidised, centuries, one, rd, late, nd,
# Nearest to of: the, a, and, in, by, also, or, one,
# Nearest to two: zero, five, six, one, four, three, seven, eight,
# Nearest to where: in, ilmarinen, their, some, such, wpm, result, aquarius,
# Nearest to by: of, the, a, and, into, for, to, one,
# Nearest to animals: artiodactyla, carnivores, chordates, komodo, human, aquatic, deer, humans,
# Nearest to shown: very, sectioning, feud, connective, documentaries, invalid, lcms, andhra,
# Nearest to applied: tars, scalia, applying, unter, customarily, waka, navies, alternator,
# Nearest to alternative: retailer, erd, practice, potencies, assumptions, dugme, ttern, reminded,
# Nearest to assembly: aiding, legislative, optimize, prentice, wharton, complaints, gir, congress,
# Nearest to ice: generalisations, desmond, canada, correggio, cream, manslaughter, motions, frozen,
# Nearest to woman: nationality, fertility, children, serling, her, adjective, birth, girl,
# Nearest to defense: selects, widows, heraldic, government, sayed, iran, militaries, overseen,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7068 0.0442 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7664 0.0389 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.7928 0.0402 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7519 0.0415 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7541 0.0421 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8609 0.0417 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.7690 0.0400 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7912 0.0400 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.7760 0.0420 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.7783 0.0385 sec/batch
# Nearest to while: glass, duma, briefly, ministered, in, on, and, pleated,
# Nearest to more: much, provability, most, often, perversity, anytime, two, number,
# Nearest to years: days, five, female, year, half, structure, seven, ago,
# Nearest to th: century, early, subsidised, centuries, one, rd, late, nd,
# Nearest to of: a, the, and, in, by, which, one, also,
# Nearest to two: zero, five, one, six, four, three, seven, eight,
# Nearest to where: in, ilmarinen, their, such, e, wpm, some, aquarius,
# Nearest to by: the, of, a, and, to, as, one, into,
# Nearest to animals: artiodactyla, chordates, komodo, carnivores, human, deer, aquatic, humans,
# Nearest to shown: very, feud, connective, sectioning, kate, documentaries, each, lcms,
# Nearest to applied: scalia, tars, applying, unter, etudes, customarily, alternator, waka,
# Nearest to alternative: retailer, erd, assumptions, potencies, practice, dugme, ttern, beetles,
# Nearest to assembly: legislative, aiding, optimize, prentice, wharton, congress, complaints, marangella,
# Nearest to ice: generalisations, desmond, correggio, canada, hypothesised, frozen, manslaughter, cream,
# Nearest to woman: nationality, serling, children, fertility, her, girl, birth, srpska,
# Nearest to defense: selects, heraldic, widows, sayed, militaries, referral, iran, facilities,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.7679 0.0410 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8024 0.0417 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7727 0.0409 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.7849 0.0382 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8098 0.0403 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.7795 0.0413 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8218 0.0421 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.7855 0.0416 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7699 0.0420 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7530 0.0420 sec/batch
# Nearest to while: more, in, briefly, much, glass, duma, pleated, and,
# Nearest to more: most, much, often, while, perversity, generally, provability, airway,
# Nearest to years: days, five, female, seven, half, structure, year, thirty,
# Nearest to th: early, century, centuries, subsidised, one, late, rd, zero,
# Nearest to of: a, the, by, and, in, which, also, or,
# Nearest to two: zero, five, six, one, four, three, seven, eight,
# Nearest to where: in, ilmarinen, some, their, wpm, such, are, e,
# Nearest to by: the, of, a, to, and, as, was, one,
# Nearest to animals: artiodactyla, carnivores, chordates, humans, komodo, deer, aquatic, starters,
# Nearest to shown: very, feud, sectioning, documentaries, kate, connective, andhra, invalid,
# Nearest to applied: scalia, applying, tars, customarily, unter, modeled, etudes, materially,
# Nearest to alternative: retailer, erd, assumptions, potencies, dugme, practice, ttern, this,
# Nearest to assembly: aiding, prentice, wharton, complaints, legislative, optimize, marangella, homage,
# Nearest to ice: generalisations, canada, correggio, desmond, manslaughter, frozen, cream, rims,
# Nearest to woman: nationality, fertility, serling, children, her, adjective, girl, female,
# Nearest to defense: selects, iran, heraldic, referral, widows, militaries, sayed, facilities,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8364 0.0410 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.7713 0.0398 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9106 0.0401 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8312 0.0420 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8585 0.0395 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.7378 0.0386 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7317 0.0392 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8085 0.0390 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.6934 0.0391 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.7964 0.0405 sec/batch
# Nearest to while: duma, pleated, in, briefly, glass, more, and, on,
# Nearest to more: most, much, often, provability, perversity, airway, two, number,
# Nearest to years: days, five, female, two, seven, year, four, half,
# Nearest to th: century, early, subsidised, centuries, one, rd, late, florin,
# Nearest to of: the, a, and, in, by, which, also, with,
# Nearest to two: zero, five, one, six, four, three, seven, eight,
# Nearest to where: in, ilmarinen, such, their, e, wpm, some, result,
# Nearest to by: the, of, a, and, to, as, was, one,
# Nearest to animals: artiodactyla, carnivores, komodo, chordates, deer, humans, aquatic, coyote,
# Nearest to shown: very, sectioning, feud, kate, andhra, connective, alg, tubulidentata,
# Nearest to applied: applying, scalia, tars, unter, materially, etudes, customarily, axopods,
# Nearest to alternative: assumptions, erd, retailer, dugme, potencies, practice, ttern, cliche,
# Nearest to assembly: aiding, legislative, prentice, wharton, complaints, marangella, congress, optimize,
# Nearest to ice: generalisations, correggio, desmond, manslaughter, canada, hbo, productions, cream,
# Nearest to woman: nationality, fertility, serling, children, adjective, birth, female, her,
# Nearest to defense: widows, selects, militaries, iran, heraldic, facilities, overseen, sayed,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.7767 0.0423 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.7675 0.0405 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-0c98ebed17c9> in <module>()
#       1 fig, ax = plt.subplots(figsize=(14, 14))
# ----> 2 for idx in range(viz_words):
#       3     plt.scatter(*embed_tsne[idx, :], color='steelblue')
#       4     plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
#
# NameError: name 'viz_words' is not defined
